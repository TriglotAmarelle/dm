# %% [markdown]
# ANR: 190450

# %%
# %matplotlib inline
import warnings
warnings.simplefilter(action='ignore')

# %%
import pandas as pd
df = pd.DataFrame.from_csv('/srv/data-mining/data/Titanic/titanic.csv',
index_col='PassengerId')
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# ...

# %%
df.count()
# Out:
# Survived    891
# Pclass      891
# Name        891
# Sex         891
# Age         714
# SibSp       891
# Parch       891
# Ticket      891
# Fare        891
# Cabin       204
# Embarked    889
# dtype: int64

# %%
df.count(axis=0,level=None, numeric_only=False)
# Out:
# Survived    891
# Pclass      891
# Name        891
# Sex         891
# Age         714
# SibSp       891
# Parch       891
# Ticket      891
# Fare        891
# Cabin       204
# Embarked    889
# dtype: int64

# %%
df.count(axis=1)
# Out:
# PassengerId
# 1      10
# 2      11
# 3      10
# 4      11
# 5      10
# 6       9
# 7      11
# 8      10
# 9      10
# 10     10
# 11     11
# 12     11
# 13     10
# 14     10
# 15     10
# 16     10
# 17     10
# 18      9
# 19     10
# 20      9
# 21     10
# 22     11
# 23     10
# 24     11
# 25     10
# 26     10
# 27      9
# 28     11
# 29      9
# 30      9
#        ..
# 862    10
# 863    11
# 864     9
# 865    10
# 866    10
# 867    10
# 868    11
# 869     9
# 870    10
# 871    10
# 872    11
# 873    11
# 874    10
# 875    10
# 876    10
# 877    10
# 878    10
# 879     9
# 880    11
# 881    10
# 882    10
# 883    10
# 884    10
# 885    10
# 886    10
# 887    10
# 888    11
# 889     9
# 890    11
# 891    10
# dtype: int64

# %% [markdown]
# Task 1
#
# There are data for 891 persons in this dataset, while the actual number of passengers and crew was estimated to be 1317, therefore some of the data is missing. In addition, there are NA values throughout the dataset, for example, in the "Cabin" feature.
#
# The features that are not clear to me are "Parch" and "SibSp".
#
# The information potentially helpful to determine who the crew members were could be the fare paid.

# %%
df['Fare']
# Out:
# PassengerId
# 1        7.2500
# 2       71.2833
# 3        7.9250
# 4       53.1000
# 5        8.0500
# 6        8.4583
# 7       51.8625
# 8       21.0750
# 9       11.1333
# 10      30.0708
# 11      16.7000
# 12      26.5500
# 13       8.0500
# 14      31.2750
# 15       7.8542
# 16      16.0000
# 17      29.1250
# 18      13.0000
# 19      18.0000
# 20       7.2250
# 21      26.0000
# 22      13.0000
# 23       8.0292
# 24      35.5000
# 25      21.0750
# 26      31.3875
# 27       7.2250
# 28     263.0000
# 29       7.8792
# 30       7.8958
#          ...
# 862     11.5000
# 863     25.9292
# 864     69.5500
# 865     13.0000
# 866     13.0000
# 867     13.8583
# 868     50.4958
# 869      9.5000
# 870     11.1333
# 871      7.8958
# 872     52.5542
# 873      5.0000
# 874      9.0000
# 875     24.0000
# 876      7.2250
# 877      9.8458
# 878      7.8958
# 879      7.8958
# 880     83.1583
# 881     26.0000
# 882      7.8958
# 883     10.5167
# 884     10.5000
# ...

# %%
df[['Name', 'Fare']]
# Out:
#                                                           Name      Fare
# PassengerId
# 1                                      Braund, Mr. Owen Harris    7.2500
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...   71.2833
# 3                                       Heikkinen, Miss. Laina    7.9250
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)   53.1000
# 5                                     Allen, Mr. William Henry    8.0500
# 6                                             Moran, Mr. James    8.4583
# 7                                      McCarthy, Mr. Timothy J   51.8625
# 8                               Palsson, Master. Gosta Leonard   21.0750
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)   11.1333
# 10                         Nasser, Mrs. Nicholas (Adele Achem)   30.0708
# 11                             Sandstrom, Miss. Marguerite Rut   16.7000
# 12                                    Bonnell, Miss. Elizabeth   26.5500
# ...

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df.groupby('Sex')['Pclass'].value_counts()
# Out:
# Sex     Pclass
# female  3         144
#         1          94
#         2          76
# male    3         347
#         1         122
#         2         108
# Name: Pclass, dtype: int64

# %%
df.groupby('Sex').count()
# Out:
#         Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  Cabin  \
# Sex
# female       314     314   314  261    314    314     314   314     97
# male         577     577   577  453    577    577     577   577    107
#
#         Embarked
# Sex
# female       312
# male         577

# %%
df.groupby('Survived')['Fare'].plot(kind='kde', legend=True)
# Out:
# Survived
# 0    Axes(0.125,0.125;0.775x0.755)
# 1    Axes(0.125,0.125;0.775x0.755)
# Name: Fare, dtype: object

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
df.groupby('Survived')['Fare'].plot(kind='kde', legend=True)
# Out:
# Survived
# 0    Axes(0.125,0.125;0.775x0.755)
# 1    Axes(0.125,0.125;0.775x0.755)
# Name: Fare, dtype: object

# %%
df.groupby('Survived')['Sex'].value_counts().plot(kind='Bar')

# %%
df['Age'] = df['Age'].fillna(0)

# %%
df.groupby(['Sex', 'Pclass'])['Survived'].value_counts().plot(kind='Bar')

# %%
df.groupby(['Sex', 'Pclass'])['Survived'].mean().plot(kind='Bar')

# %%
df.groupby('Survived')['Sex'].value_counts().plot(kind='Bar')

# %%
df.groupby('Survived')['Pclass'].value_counts().plot(kind='Bar')

# %% [markdown]
# Task 2
#
# A high mortality rate can be spotted among the 3rd class, and among men.
#
# The first people allowed to evacuate the ship were children and women.

# %%
died_subset = df[df['Survived'] == 0]

# %%
live_subset = df[df['Survived'] != 0]

# %%
df.plot(x='Age', y='Fare', kind='scatter')

# %%
from scipy.stats import pearsonr
df['Age'].fillna(0)
pearsonr(df['Age'], df['Fare'])
# Out:
# (0.13551585352705101, 4.9462438889547957e-05)

# %%
df['Sex'] = pd.get_dummies(df['Sex'])
died_subset = df[df['Survived'] == 0]
live_subset = df[df['Survived'] != 0]

# %%
df.plot(x='Sex', y='Pclass', kind='scatter')

# %%
ax1 = died_subset.plot(x='Age', y='Fare',
label='Died', color='red', kind='scatter')
ax2 = live_subset.plot(x='Age', y='Fare',
label='Survived', color='green', kind='scatter',
ax=ax1)
ax2

# %%
df['Sex'] = pd.get_dummies(df['Sex'])
died_subset = df[df['Survived'] == 0]
live_subset = df[df['Survived'] != 0]

# %%
ax1 = died_subset.plot(x='Sex', y='Pclass',
label='Died', color='red', kind='scatter')
ax2 = live_subset.plot(x='Sex', y='Pclass',
label='Survived', color='green', kind='scatter',
ax=ax1)
ax2

# %% [markdown]
# Task 3
#
# Sex and Class are not particularly revealing from the plot.
# Age and Fare do not seem to correlate according to the plot.
# Most people who paid more for the fair survived, and people older than 40 had lower survival rates.

# %%
df.boxplot(column=['Fare'], by='Survived')

# %% [markdown]
# Task 4
#
# The difference in the possibility of survival is rather evident in the two cases. The chances of survival seem to be higher if the fare exceeds 50.
